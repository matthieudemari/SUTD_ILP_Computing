# %% [markdown]
# # Activity 2 - TicTacToe
#
# ### Problem statement

# %% [markdown]
# A tic tac toe bord can be represented as a list of lists.
#
# ![3d-tic-tac-toe-tic-tac-toe-png-favpng-xzNT32BhZYkMVgtA4Qu8gxvhW.jpg](attachment:3d-tic-tac-toe-tic-tac-toe-png-favpng-xzNT32BhZYkMVgtA4Qu8gxvhW.jpg)

# %% [markdown]
# For instance, the board above can be represented as the following list of lists, by
# - defining a list of three elements,
# - each element is a sublist of three elements corresponding to each line, from up to down,
# - each sublist contains three elements, corresponding to each position on the line, from left to right,
# - each element will have a value 0 if the position is empty,
# - each element will have a value 1 if the position contains a circle,
# - each element will have a value 2 if the position contains a cross,

# %%
board = [[1, 2, 2], \
         [0, 1, 2], \
         [2, 1, 1]]

# %%
board = [[1, 2, 2], [0, 1, 2], [2, 1, 1]]

# %% [markdown]
# ### Task
#
# Write a function **board_winner()**, which:
# - receives a board, as defined above, as its sole input parameter,
# - returns a single output, which consists of the value $ 1 $ if the circles won, $ 2 $ if the crosses won, and $ 0 $ if there is no clear winner.

# %% [markdown]
# ### Your code below!

# %%
def board_winner(board):
    winner = None
    return winner

# %% [markdown]
# ### Expected results (for all possible outcomes!)

# %%
board1 = [[1, 2, 2], \
         [0, 1, 2], \
         [2, 1, 1]]
# This should print 1, as 1's have the diagonal.
print(board_winner(board1))

# %%
board2 = [[2, 2, 2], \
         [1, 1, 2], \
         [2, 1, 1]]
# This should print 2, as 2's have the first horizontal line.
print(board_winner(board2))

# %%
board3 = [[0, 0, 0], \
         [1, 1, 1], \
         [2, 2, 0]]
# This should print 1, as 1's have the second horizontal line.
print(board_winner(board3))

# %%
board4 = [[1, 2, 0], \
         [1, 1, 0], \
         [2, 2, 2]]
# This should print 2, as 2's have the third horizontal line.
print(board_winner(board4))

# %%
board5 = [[1, 0, 2], \
         [1, 1, 0], \
         [1, 2, 2]]
# This should print 1, as 1's have the first vertical line.
print(board_winner(board5))

# %%
board6 = [[1, 2, 0], \
         [1, 2, 0], \
         [2, 2, 1]]
# This should print 2, as 2's have the second vertical line.
print(board_winner(board6))

# %%
board7 = [[1, 2, 2], \
         [1, 1, 2], \
         [2, 1, 2]]
# This should print 2, as 2's have the third vertical line.
print(board_winner(board7))

# %%
board8 = [[1, 2, 1], \
         [2, 1, 0], \
         [1, 2, 2]]
# This should print 1, as 1's have the second diagonal line.
print(board_winner(board8))

# %%
board9 = [[1, 2, 1], \
         [1, 1, 2], \
         [2, 1, 2]]
# This should print 0, as there is no clear winner on this board.
print(board_winner(board9))
